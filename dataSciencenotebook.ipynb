# %% [markdown]
# <a href="https://colab.research.google.com/github/meenu618/meenu618/blob/main/dataSciencenotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
import pandas as pd
import os
os.getcwd()
df = pd.read_csv("https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv") ##"C:/Users/Menuka Jain/Downloads/customers-100.csv")
print("Head is",df.head())
print("Shape is",df.shape)
print("columns are",df.columns)
top_ten_country = list(df["Country"].tail(10).values)
print("Top ten countries areee",top_ten_country)
#df_sugar = pdread_csv("https://raw.githubusercontent.com/noahgift/sugar/master/data/education_sugar_cdc_2000.csv")
# Out:
# Head is          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0
# Shape is (161568, 5)
# columns are Index(['Date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')
# Top ten countries areee ['Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe']

# %% [markdown]
# ## EDA

# %%
print("ata description is ",df.describe())
import seaborn as sns
sns.scatterplot(x="Country",y="Deaths",hue="Deaths",size="Deaths",data=df)
# Out:
# ata description is            Confirmed     Recovered         Deaths
# count  1.615680e+05  1.615680e+05  161568.000000
# mean   7.361569e+05  1.453967e+05   13999.436089
# std    3.578884e+06  9.748275e+05   59113.581271
# min    0.000000e+00  0.000000e+00       0.000000
# 25%    1.220000e+03  0.000000e+00      17.000000
# 50%    2.369200e+04  1.260000e+02     365.000000
# 75%    2.558420e+05  1.797225e+04    4509.000000
# max    8.062512e+07  3.097475e+07  988609.000000

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Classification Algorithm 1

# %% [markdown]
# ### Classification Algorithm 2

# %% [markdown]
# ## Conclusion
